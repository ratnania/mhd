# %%
import numpy as np
import matplotlib.pyplot as plt
import Utilitis_HybridCode as utils

# %% [markdown]
# # GEMPIC

# %% [markdown]
# # 1. Lie-Trotter splitting

# %% [markdown]
# ## 1.1 Lie-Trotter splitting without Control Variate (p=1)

# %%
data1 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=1_FirstLie_NoCV')

en_B1  = data1[:, 0]
en_E1  = data1[:, 1]
en_C1  = data1[:, 2]
en_H1  = data1[:, 3]

# %%
f1 = plt.figure()
f1.set_figheight(4)
f1.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot1 = en_B1 + en_E1 + en_C1 + en_H1

Nt = len(en_B1) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B1/en_tot1[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E1/en_tot1[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C1/en_tot1[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H1/en_tot1[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Energies_GEMPIC_LieTrotter_p=1_NoCV.pdf', bbox_inches = 'tight')

# %%
f2 = plt.figure()
f2.set_figheight(4)
f2.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot1 = en_B1 + en_E1 + en_C1 + en_H1

Nt = len(en_B1) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot1 - en_tot1[0])/en_tot1[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Conservation_GEMPIC_LieTrotter_p=1_NoCV.pdf', bbox_inches = 'tight')

# %% [markdown]
# ## 1.2 Lie-Trotter splitting without Control Variate (p=2)

# %%
data2 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=2_FirstLie_NoCV')

en_B2  = data2[:, 0]
en_E2  = data2[:, 1]
en_C2  = data2[:, 2]
en_H2  = data2[:, 3]

# %%
f3 = plt.figure()
f3.set_figheight(4)
f3.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot2 = en_B2 + en_E2 + en_C2 + en_H2

Nt = len(en_B2) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B2/en_tot2[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E2/en_tot2[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C2/en_tot2[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H2/en_tot2[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_LieTrotter_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f4 = plt.figure()
f4.set_figheight(4)
f4.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot2 = en_B2 + en_E2 + en_C2 + en_H2

Nt = len(en_B2) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot2 - en_tot2[0])/en_tot2[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_LieTrotter_p=2_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# ## 1.3 Lie-Trotter splitting without Control Variate (p=3)

# %%
data3 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=3_FirstLie_NoCV')

en_B3  = data3[:, 0]
en_E3  = data3[:, 1]
en_C3  = data3[:, 2]
en_H3  = data3[:, 3]

# %%
f5 = plt.figure()
f5.set_figheight(4)
f5.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot3 = en_B3 + en_E3 + en_C3 + en_H3

Nt = len(en_B3) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B3/en_tot3[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E3/en_tot3[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C3/en_tot3[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H3/en_tot3[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_LieTrotter_p=3_NoCV.pdf', bbox_inches = 'tight')

# %%
f6 = plt.figure()
f6.set_figheight(4)
f6.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot3 = en_B3 + en_E3 + en_C3 + en_H3

Nt = len(en_B3) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot3 - en_tot3[0])/en_tot3[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_LieTrotter_p=3_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# ## 1. 4 Lie-Trotter splitting with Control Variate (p=1)

# %%
data4 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=1_FirstLie_WithCV')

en_B4  = data4[:, 0]
en_E4  = data4[:, 1]
en_C4  = data4[:, 2]
en_H4  = data4[:, 3]

# %%
f7 = plt.figure()
f7.set_figheight(4)
f7.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot4 = en_B4 + en_E4 + en_C4 + en_H4

Nt = len(en_B4) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 150, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B4/en_tot4[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E4/en_tot4[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C4/en_tot4[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H4/en_tot4[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 2e-8*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-12, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Energies_GEMPIC_LieTrotter_p=1_WithCV.pdf', bbox_inches = 'tight')

# %%
f8 = plt.figure()
f8.set_figheight(4)
f8.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot4 = en_B4 + en_E4 + en_C4 + en_H4

Nt = len(en_B4) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot4 - en_tot4[0])/en_tot4[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_LieTrotter_p=1_WithCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 2. Strang splitting

# %% [markdown]
# ## 2.1 Strang splitting without Control Variate (p=1)

# %%
data5 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=1_SecondStrang_NoCV')

en_B5  = data5[:, 0]
en_E5  = data5[:, 1]
en_C5  = data5[:, 2]
en_H5  = data5[:, 3]

# %%
f9 = plt.figure()
f9.set_figheight(4)
f9.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot5 = en_B5 + en_E5 + en_C5 + en_H5

Nt = len(en_B5) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B5/en_tot5[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E5/en_tot5[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C5/en_tot5[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H5/en_tot5[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')

# %%
f10 = plt.figure()
f10.set_figheight(4)
f10.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot5 = en_B5 + en_E5 + en_C5 + en_H5

Nt = len(en_B5) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot5 - en_tot5[0])/en_tot5[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# ## 2.2 Strang splitting without Control Variate (p=2)

# %%
data6 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=2_SecondStrang_NoCV')

en_B6  = data6[:, 0]
en_E6  = data6[:, 1]
en_C6  = data6[:, 2]
en_H6  = data6[:, 3]

# %%
f11 = plt.figure()
f11.set_figheight(4)
f11.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot6 = en_B6 + en_E6 + en_C6 + en_H6

Nt = len(en_B6) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B6/en_tot6[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E6/en_tot6[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C6/en_tot6[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H6/en_tot6[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f12 = plt.figure()
f12.set_figheight(4)
f12.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot6 = en_B6 + en_E6 + en_C6 + en_H6

Nt = len(en_B6) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot6 - en_tot6[0])/en_tot6[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# ## 2.3 Strang splitting without Control Variate (p=3)

# %%
data7 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=3_SecondStrang_NoCV')

en_B7  = data7[:, 0]
en_E7  = data7[:, 1]
en_C7  = data7[:, 2]
en_H7  = data7[:, 3]

# %%
f13 = plt.figure()
f13.set_figheight(4)
f13.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot7 = en_B7 + en_E7 + en_C7 + en_H7

Nt = len(en_B7) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B7/en_tot7[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E7/en_tot7[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C7/en_tot7[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H7/en_tot7[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f14 = plt.figure()
f14.set_figheight(4)
f14.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot7 = en_B7 + en_E7 + en_C7 + en_H7

Nt = len(en_B7) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot7 - en_tot7[0])/en_tot7[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# ## 2.4 Strang splitting with Control Variate (p=1)

# %%
data8 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/learning-python/data_Nel=32_dt=0.0125_Np=1e5_T=200_amp=1e-4_p=1_SecondStrang_WithCV')

en_B8  = data8[:, 0]
en_E8  = data8[:, 1]
en_C8  = data8[:, 2]
en_H8  = data8[:, 3]

# %%
f15 = plt.figure()
f15.set_figheight(4)
f15.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot8 = en_B8 + en_E8 + en_C8 + en_H8

Nt = len(en_B8) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 150, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B8/en_tot8[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E8/en_tot8[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C8/en_tot8[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H8/en_tot8[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 2e-8*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-12, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_LieTrotter_p=1_WithCV.pdf', bbox_inches = 'tight')

# %%
f16 = plt.figure()
f16.set_figheight(4)
f16.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot8 = en_B8 + en_E8 + en_C8 + en_H8

Nt = len(en_B8) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot8 - en_tot8[0])/en_tot8[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 3. Comparison splitting methods (without Control Variate)

# %%
f17 = plt.figure()
f17.set_figheight(4)
f17.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot1 = en_B1 + en_E1 + en_C1 + en_H1
en_tot5 = en_B5 + en_E5 + en_C5 + en_H5

Nt = len(en_B1) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot1 - en_tot1[0])/en_tot1[0], linewidth = 2, color = 'darkorange', label = 'Lie-Trotter')
plt.semilogy(tn, np.abs(en_tot5 - en_tot5[0])/en_tot5[0], linewidth = 2, color = 'purple', label = 'Strang')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
plt.legend(loc = 'upper right')
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_LieTrotter_p=1_NoCV.pdf', bbox_inches = 'tight')

# %% [markdown]
# # 4. Comparison with and without CV

# %%
f18 = plt.figure()
f18.set_figheight(4)
f18.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot1 = en_B1 + en_E1 + en_C1 + en_H1
en_tot4 = en_B4 + en_E4 + en_C4 + en_H4

Nt = len(en_B1) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot1 - en_tot1[0])/en_tot1[0], linewidth = 2, color = 'purple', label = 'No CV')
plt.semilogy(tn, np.abs(en_tot4 - en_tot4[0])/en_tot4[0], linewidth = 2, color = 'darkorange', label = 'With CV')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e0))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy (Lie-Trotter)', fontsize = fontsize)
plt.legend(loc = 'upper left')
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Conservation_GEMPIC_LieTrotter_p=1_WithCV.pdf', bbox_inches = 'tight')

# %% [markdown]
# # Standard

# %% [markdown]
# # 1. Without Control Variate (N=1e5)

# %%
data9 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/03_ParticleScan/data_T=200_N=32_dt=0.0125_p=1_Np=1e5_amp=1e-4_NoCV.txt')

en_E9  = data9[1:, -5]
en_B9  = data9[1:, -4]
en_C9  = data9[1:, -3]
en_H9  = data9[1:, -2]

# %%
f19 = plt.figure()
f19.set_figheight(4)
f19.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot9 = en_B9 + en_E9 + en_C9 + en_H9

Nt = len(en_B9) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B9/en_tot9[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E9/en_tot9[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C9/en_tot9[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H9/en_tot9[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f20 = plt.figure()
f20.set_figheight(4)
f20.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot9 = en_B9 + en_E9 + en_C9 + en_H9

Nt = len(en_B9) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot9 - en_tot9[0])/en_tot9[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 2. Without Control Variate (N=5e5)

# %%
data10 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/03_ParticleScan/data_T=200_N=32_dt=0.0125_p=1_Np=5e5_amp=1e-4_NoCV.txt')

en_E10  = data10[1:, -5]
en_B10  = data10[1:, -4]
en_C10  = data10[1:, -3]
en_H10  = data10[1:, -2]

# %%
f21 = plt.figure()
f21.set_figheight(4)
f21.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot10 = en_B10 + en_E10 + en_C10 + en_H10

Nt = len(en_B10) - 1
dt = 0.05/4*2
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B10/en_tot10[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E10/en_tot10[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C10/en_tot10[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H10/en_tot10[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f22 = plt.figure()
f22.set_figheight(4)
f22.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot10 = en_B10 + en_E10 + en_C10 + en_H10

Nt = len(en_B10) - 1
dt = 0.05/4*2
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot10 - en_tot10[0])/en_tot10[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 3. Without Control Variate (N=1e6)

# %%
data11 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/03_ParticleScan/data_T=200_N=32_dt=0.0125_p=1_Np=1e6_amp=1e-4_NoCV.txt')

en_E11  = data11[1:, -5]
en_B11  = data11[1:, -4]
en_C11  = data11[1:, -3]
en_H11  = data11[1:, -2]

# %%
f23 = plt.figure()
f23.set_figheight(4)
f23.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot11 = en_B11 + en_E11 + en_C11 + en_H11

Nt = len(en_B11) - 1
dt = 0.05/4*2
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B11/en_tot11[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E11/en_tot11[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C11/en_tot11[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H11/en_tot11[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f24 = plt.figure()
f24.set_figheight(4)
f24.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot11 = en_B11 + en_E11 + en_C11 + en_H11

Nt = len(en_B11) - 1
dt = 0.05/4*2
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot11 - en_tot11[0])/en_tot11[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 4. Without Control Variate (N=5e6)

# %%
data12 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/03_ParticleScan/data_T=200_N=32_dt=0.0125_p=1_Np=5e6_amp=1e-4_NoCV.txt')

en_E12  = data12[1:, -5]
en_B12  = data12[1:, -4]
en_C12  = data12[1:, -3]
en_H12  = data12[1:, -2]

# %%
f25 = plt.figure()
f25.set_figheight(4)
f25.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot12 = en_B12 + en_E12 + en_C12 + en_H12

Nt = len(en_B12) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B12/en_tot12[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E12/en_tot12[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C12/en_tot12[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H12/en_tot12[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f26 = plt.figure()
f26.set_figheight(4)
f26.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot12 = en_B12 + en_E12 + en_C12 + en_H12

Nt = len(en_B12) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot12 - en_tot12[0])/en_tot12[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 5. Without Control Variate (N=1e7)

# %%
data13 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/03_ParticleScan/data_T=200_N=32_dt=0.0125_p=1_Np=1e7_amp=1e-4_NoCV.txt')

en_E13  = data13[1:, -5]
en_B13  = data13[1:, -4]
en_C13  = data13[1:, -3]
en_H13  = data13[1:, -2]

# %%
f26 = plt.figure()
f26.set_figheight(4)
f26.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot13 = en_B13 + en_E13 + en_C13 + en_H13

Nt = len(en_B13) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B13/en_tot13[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E13/en_tot13[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C13/en_tot13[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H13/en_tot13[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_Strang_p=2_NoCV.pdf', bbox_inches = 'tight')

# %%
f28 = plt.figure()
f28.set_figheight(4)
f28.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot13 = en_B13 + en_E13 + en_C13 + en_H13

Nt = len(en_B13) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot13 - en_tot13[0])/en_tot13[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')

# %% [markdown]
# # 6. Comparison particle scan

# %% [markdown]
# ## 6.1 Magnetic field

# %%
f29 = plt.figure()
f29.set_figheight(4)
f29.set_figwidth(6)

fontsize = 24
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)


Nt1 = len(en_B13) - 1
Nt2 = len(en_B10) - 1

dt1 = 0.05/4
dt2 = 0.05/4*2

tn1 = np.linspace(0, Nt1*dt1, Nt1 + 1) 
tn2 = np.linspace(0, Nt2*dt2, Nt2 + 1) 

tg = np.linspace(0, 120, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue', 'red', 'green']
labels = ['$N_\mathrm{p}=1\cdot 10^5$', '$N_\mathrm{p}=5\cdot 10^5$', '$N_\mathrm{p}=1\cdot 10^6$', '$N_\mathrm{p}=5\cdot 10^6$', '$N_\mathrm{p}=1\cdot 10^7$', 'CV ($N_\mathrm{p}=1\cdot 10^5$)']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]

omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn1, en_B9/en_tot9[0], linewidth = 2, label = labels[0], color = colors[0])
plt.semilogy(tn2, en_B10/en_tot10[0], linewidth = 2, label = labels[1], color = colors[1])
plt.semilogy(tn2, en_B11/en_tot11[0], linewidth = 2, label = labels[2], color = colors[2])
plt.semilogy(tn1, en_B12/en_tot12[0], linewidth = 2, label = labels[3], color = colors[3])
plt.semilogy(tn1, en_B13/en_tot13[0], linewidth = 2, label = labels[4], color = colors[4])
plt.semilogy(tn1, en_B14/en_tot14[0], linewidth = 2, label = labels[5], color = colors[5])

plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E}_{\tilde{B}} / \mathcal{E}(0)$')
plt.title('Convergence for different particle numbers', fontsize = fontsize)
plt.ylim((1e-10, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'upper center', ncol = 1, bbox_to_anchor = (1.45, 1.05))
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Convergence_particles.pdf', bbox_inches = 'tight')

# %% [markdown]
# ## 6.2 Energy conservation

# %%
f30 = plt.figure()
f30.set_figheight(4)
f30.set_figwidth(6)

fontsize = 24
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)


Nt1 = len(en_B13) - 1
Nt2 = len(en_B10) - 1

dt1 = 0.05/4
dt2 = 0.05/4*2

tn1 = np.linspace(0, Nt1*dt1, Nt1 + 1) 
tn2 = np.linspace(0, Nt2*dt2, Nt2 + 1) 

colors = ['darkorange', 'purple', 'sienna', 'royalblue', 'red', 'green']
labels = ['$N_\mathrm{p}=1\cdot 10^5$', '$N_\mathrm{p}=5\cdot 10^5$', '$N_\mathrm{p}=1\cdot 10^6$', '$N_\mathrm{p}=5\cdot 10^6$', '$N_\mathrm{p}=1\cdot 10^7$', 'CV ($N_\mathrm{p}=1\cdot 10^5$)']

plt.semilogy(tn1, np.abs(en_tot9 - en_tot9[0])/en_tot9[0], linewidth = 2, color = colors[0], label = labels[0])
plt.semilogy(tn2, np.abs(en_tot10 - en_tot10[0])/en_tot10[0], linewidth = 2, color = colors[1], label = labels[1])
plt.semilogy(tn2, np.abs(en_tot11 - en_tot11[0])/en_tot11[0], linewidth = 2, color = colors[2], label = labels[2])
plt.semilogy(tn1, np.abs(en_tot12 - en_tot12[0])/en_tot12[0], linewidth = 2, color = colors[3], label = labels[3])
plt.semilogy(tn1, np.abs(en_tot13 - en_tot13[0])/en_tot13[0], linewidth = 2, color = colors[4], label = labels[4])
plt.semilogy(tn1, np.abs(en_tot14 - en_tot14[0])/en_tot14[0], linewidth = 2, color = colors[5], label = labels[5])

plt.xlim((0, 200))
plt.ylim((1e-12, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
plt.legend(loc = 'upper center', ncol = 1, bbox_to_anchor = (1.45, 1.05))
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Convergence_particles_2.pdf', bbox_inches = 'tight')

# %% [markdown]
# ## 7. Comparison with GEMPiC

# %%
f31 = plt.figure()
f31.set_figheight(4)
f31.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)


en_tot5 = en_B5 + en_E5 + en_C5 + en_H5

Nt5 = len(en_B5) - 1
dt5 = 0.05/4
tn5 = np.linspace(0, Nt5*dt5, Nt5 + 1)

en_tot9 = en_B9 + en_E9 + en_C9 + en_H9

Nt9 = len(en_B9) - 1
dt9 = 0.05/4
tn9 = np.linspace(0, Nt9*dt9, Nt9 + 1)

tg = np.linspace(0, 120, 100)

colors = ['purple', 'sienna', 'darkorange', 'royalblue', 'red']
labels = ['Geometric (Lie-Trotter)', 'Geometric (Strang)', 'Standard', '$5\cdot 10^6$', '$1\cdot 10^7$']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]

omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn1, en_B1/en_tot1[0], linewidth = 2, label = labels[0], color = colors[0])
plt.semilogy(tn5, en_B5/en_tot5[0], linewidth = 2, label = labels[1], color = colors[1])
plt.semilogy(tn9, en_B9/en_tot9[0], linewidth = 2, label = labels[2], color = colors[2])

plt.semilogy(tg, 5e-6*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E}_{\tilde{B}} / \mathcal{E}(0)$')
plt.title('Magnetic field energy', fontsize = fontsize)
plt.ylim((1e-8, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'upper center', ncol = 1, bbox_to_anchor = (1.5, 1.03))
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Comparison_GEM_Standard_1.pdf', bbox_inches = 'tight')

# %%
f31 = plt.figure()
f31.set_figheight(4)
f31.set_figwidth(6)

fontsize = 23
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot5 = en_B5 + en_E5 + en_C5 + en_H5

Nt5 = len(en_B5) - 1
dt5 = 0.05/4
tn5 = np.linspace(0, Nt5*dt5, Nt5 + 1)

en_tot9 = en_B9 + en_E9 + en_C9 + en_H9

Nt9 = len(en_B9) - 1
dt9 = 0.05/4
tn9 = np.linspace(0, Nt9*dt9, Nt9 + 1)



plt.semilogy(tn1, np.abs(en_tot1 - en_tot1[0])/en_tot1[0], linewidth = 2, color = 'purple', label = 'Geometric (Lie-Trotter)')
plt.semilogy(tn5, np.abs(en_tot5 - en_tot5[0])/en_tot5[0], linewidth = 2, color = 'sienna', label = 'Geometric (Strang)')
plt.semilogy(tn9, np.abs(en_tot9 - en_tot9[0])/en_tot9[0], linewidth = 2, color = 'darkorange', label = 'Standard')

plt.xlim((0, 200))
plt.ylim((1e-12, 1e-2))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
plt.legend(loc = 'upper center', ncol = 1, bbox_to_anchor = (1.5, 1.03))
plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/05_Results/Comparison_GEM_Standard_2.pdf', bbox_inches = 'tight')

# %% [markdown]
# ## 8. With Control Variate (p=1)

# %%
data14 = np.loadtxt('/home/florian/Schreibtisch/Masterarbeit/06_Github/mhd/02_HybridModelling/Results/01_NoDipoleField/data_T=200_N=32_dt=0.0125_p=1_Np=1e5_amp=1e-4_WithCV.txt')

en_E14  = data14[1:, -5]
en_B14  = data14[1:, -4]
en_C14  = data14[1:, -3]
en_H14  = data14[1:, -2]

# %%
f32 = plt.figure()
f32.set_figheight(4)
f32.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot14 = en_B14 + en_E14 + en_C14 + en_H14

Nt = len(en_B14) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1) 
tg = np.linspace(0, 150, 100)

colors = ['darkorange', 'purple', 'sienna', 'royalblue']

omega = utils.solveDispersionHybrid(2., +1, 1, -1, 2., 0.2, 0.53, 6e-2, 0.5 + 0j, 1e-8)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)

plt.semilogy(tn, en_B14/en_tot14[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{B}}$', color = colors[0])
plt.semilogy(tn, en_E14/en_tot14[0], linewidth = 2, label = r'$\mathcal{E}_{\tilde{E}}$', color = colors[1])
plt.semilogy(tn, en_C14/en_tot14[0], '--', linewidth = 2, label = r'$\mathcal{E}_\mathrm{c}$', color = colors[2])
plt.semilogy(tn, en_H14/en_tot14[0], linewidth = 2, label = r'$\mathcal{E}_\mathrm{h}$', color = colors[3])
plt.semilogy(tg, 2e-8*np.exp(tg*gamma*2), 'k--', linewidth = 2)

plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel(r'$\mathcal{E} / \mathcal{E}(0)$')
plt.title('Partition of energy', fontsize = fontsize)
plt.ylim((1e-12, 1e1))
plt.xlim((0, 200))
plt.legend(loc = 'lower right', ncol = 2)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Energies_GEMPIC_LieTrotter_p=1_WithCV.pdf', bbox_inches = 'tight')

# %%
f33 = plt.figure()
f33.set_figheight(4)
f33.set_figwidth(6)

fontsize = 22
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
plt.rcParams.update({'font.size': fontsize})
plt.rc('xtick', labelsize = fontsize)
plt.rc('ytick', labelsize = fontsize)

en_tot14 = en_B14 + en_E14 + en_C14 + en_H14

Nt = len(en_B14) - 1
dt = 0.05/4
tn = np.linspace(0, Nt*dt, Nt + 1)

plt.semilogy(tn, np.abs(en_tot14 - en_tot14[0])/en_tot14[0], linewidth = 2, color = 'purple')
plt.xlim((0, 200))
plt.ylim((1e-10, 1e-1))
plt.xlabel('$t|\Omega_\mathrm{ce}|$')
plt.ylabel('$|\mathcal{E}(t) - \mathcal{E}(0)|/\mathcal{E}(0)$')
plt.title('Relative error in total energy', fontsize = fontsize)
#plt.savefig('/home/florian/Schreibtisch/Masterarbeit/07_Ausarbeitung/master-thesis/01_Figures/Conservation_GEMPIC_Strang_p=1_NoCV.pdf', bbox_inches = 'tight')
# Out:
# Text(0.5,1,'Relative error in total energy')
