# %% [markdown]
# # Diagnostics of simulation results

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from matplotlib.colors import LogNorm
import Utilitis_HybridCode as utils


# ... import simulation data
#data = np.loadtxt('Results/01_WavenumberScan/simulation_data_T=400_k=2.0.txt')
data = np.loadtxt('Results/simulation_data_T=100_L=2pi_newCode.txt')
#data = np.loadtxt('Results/03_DipoleField/simulation_data_T=3000_L=327.7_xi=8.62e-5.txt')
# ...

# %%
# ... get simulation parameters
pa = data[0]

eps0  = pa[0]
mu0   = pa[1]
c     = pa[2]
qe    = pa[3]
me    = pa[4]
B0z   = pa[5]
wce   = pa[6]
wpe   = pa[7]
nuh   = pa[8]
nh    = pa[9]
wpar  = pa[10]
wperp = pa[11]
k     = pa[12]
ini   = np.int(pa[13])
amp   = pa[14]
eps   = pa[15]
Lz    = pa[16]
Nz    = np.int(pa[17])
T     = pa[18]
dt    = pa[19]
p     = np.int(pa[20])
Lv    = pa[21]
Nv    = np.int(pa[22])
Np    = np.int(pa[23])
xi    = pa[24]
Ld    = pa[25]

bcs_p = pa[26]
bcs_f = pa[27]
bcs_d = pa[28]
bcs_g = pa[29]
# ...

bcs_f = 1

# %%
# ... additional parameters 
if bcs_f == 1:
    Nb = Nz
elif bcs_f == 2:
    Nb = Nz + p - 2
s = 6
# ...



# ... discretization parameters
dz = Lz/Nz
zj = np.linspace(0, Lz, Nz + 1)

Nt = np.int(T/dt)
tn = np.linspace(0, T, Nt + 1)
# ...




# ... get simulation data

if bcs_f == 1:

    uj = data[1:, 0:s*Nb]
    yhj = data[1:, s*Nb:8*Nb]

    ejx  = uj[:, 0::6]
    ejy  = uj[:, 1::6]
    bjx  = uj[:, 2::6]
    bjy  = uj[:, 3::6]
    ycjx = uj[:, 4::6]
    ycjy = uj[:, 5::6]
    yhjx = yhj[:, 0::2]
    yhjy = yhj[:, 1::2]

elif bcs_f == 2:

    uj = data[1:, 0:s*Nb]
    yhj = data[1:, s*Nb:8*Nb]

    ejx = np.c_[np.zeros(Nt+1),uj[:,0::6],np.zeros(Nt+1)]
    ejy = np.c_[np.zeros(Nt+1),uj[:,1::6],np.zeros(Nt+1)]
    bjx = np.c_[np.zeros(Nt+1),uj[:,2::6],np.zeros(Nt+1)]
    bjy = np.c_[np.zeros(Nt+1),uj[:,3::6],np.zeros(Nt+1)]
    ycjx = np.c_[np.zeros(Nt+1),uj[:,4::6],np.zeros(Nt+1)]
    ycjy = np.c_[np.zeros(Nt+1),uj[:,5::6],np.zeros(Nt+1)]
    yhjx = yhj[:,0::2]
    yhjy = yhj[:,1::2]
# ...



def damp(z):
    return 0*z

def B0(z):
    return 0*z


# ... create B-spline basis and compute mass matrix
basis,N,quad_points,weights = utils.createBasis(Lz,Nz,p,bcs_f)
M = utils.matrixAssembly(basis,weights,quad_points,B0,bcs_f)[0]
# ...




# ... solve the dispersion relation for a fixed k to get ocillation frequency and growth rate 
omega = utils.solveDispersionHybrid(k,+1,c,wce,wpe,wpar,wperp,nuh,0.5 + 0j,1e-6,100)[0]
omega_r = np.real(omega)
gamma = np.imag(omega)
# ...





# ... compute averaged quadratic magnetic field
mean_Bx2 = np.zeros(Nt+1)
mean_B2 = np.zeros(Nt+1)

for j in range(0,Nt+1):
    mean_Bx2[j] = 1/Lz*np.dot(bjx[j],np.dot(M,bjx[j]))
    mean_B2[j] = 1/Lz*(np.dot(bjx[j],np.dot(M,bjx[j])) + np.dot(bjy[j],np.dot(M,bjy[j])))
# ...

                       
                       
# ... compute fft for frequency analysis in linear phase 
#Ntend = 2000
Ntend = Nt
spec = np.fft.fft(mean_Bx2[0:Ntend+1])
spec = np.fft.fftshift(spec)
w = np.linspace(0,Ntend,Ntend+1) - Ntend/2
w = 2*np.pi*w/(Ntend*dt)
# ...



# ... compute time-frequency spectrum
f, t, Sxx = signal.spectrogram(mean_Bx2[0:],1/dt,nperseg = 1000,noverlap = None,nfft = None)
om = 2*np.pi*f
lvls = np.logspace(-15,-6,200)
Time,Omega = np.meshgrid(t,om)
# ...

                       
# ... plot results
f1 = plt.figure()
f1.set_figheight(8)
f1.set_figwidth(12)
plt.subplots_adjust(wspace = 0.4, hspace = 0.4)

plt.subplot(221)
plt.semilogy(tn,mean_B2,label = 'numerics')
t2 = np.linspace(0,T,100)
#plt.semilogy(t2,1.2e-9*np.exp(t2*gamma*2),label = 'expected growth rate')
plt.xlabel('t |wce|')
plt.ylabel('<Bx^2 + By^2>/B0^2')
#plt.xlim((0,10000))
#plt.ylim((1e-7,1e-3))
plt.legend()

plt.subplot(222)
plt.plot(w,np.abs(spec))
plt.xlim((0.2,0.4))
plt.xlabel('w / |wce|')
plt.ylabel('spectrogram of <Bx^2 + By^2>/B0^2')
#plt.plot(np.ones(20)*2*omega_r,np.linspace(0,4e-6,20),label = 'expected real frequency')
#plt.legend()
plt.title('spectrogram in linear phase')

'''
plt.subplot(223)
plt.contourf(Time,Omega,Sxx,100,cmap = 'jet')
#plt.contourf(Time,Omega,Sxx,norm = LogNorm(),levels = lvls, cmap = 'jet')

plt.plot(np.linspace(t[0],t[-1],100),np.ones(100)*omega_r*2,'k--')
plt.xlabel('t |wce|')
plt.xlabel('w / |wce|')
plt.ylim((0,2))
plt.colorbar()
plt.title('time-frequency spectrogram')
'''
# ...
# Out:
# "\nplt.subplot(223)\nplt.contourf(Time,Omega,Sxx,100,cmap = 'jet')\n#plt.contourf(Time,Omega,Sxx,norm = LogNorm(),levels = lvls, cmap = 'jet')\n\nplt.plot(np.linspace(t[0],t[-1],100),np.ones(100)*omega_r*2,'k--')\nplt.xlabel('t |wce|')\nplt.xlabel('w / |wce|')\nplt.ylim((0,2))\nplt.colorbar()\nplt.title('time-frequency spectrogram')\n"

# %%
from Utils_Dipole.evaluation import evaluation
Bx = np.zeros(Nt+1)

for i in range(0,Nt+1):
    if i%50 == 0:
        print(i)
    Bx[i] = evaluation(bjx[i],basis,Lz/2,p,bcs_f)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950
# 12000
# 12050
# 12100
# 12150
# 12200
# 12250
# 12300
# 12350
# 12400
# 12450
# 12500
# 12550
# 12600
# 12650
# 12700
# 12750
# 12800
# 12850
# 12900
# 12950
# 13000
# 13050
# 13100
# 13150
# 13200
# 13250
# 13300
# 13350
# 13400
# 13450
# 13500
# 13550
# 13600
# 13650
# 13700
# 13750
# 13800
# 13850
# 13900
# 13950
# 14000
# 14050
# 14100
# 14150
# 14200
# 14250
# 14300
# 14350
# 14400
# 14450
# 14500
# 14550
# 14600
# 14650
# 14700
# 14750
# 14800
# 14850
# 14900
# 14950
# 15000
# 15050
# 15100
# 15150
# 15200
# 15250
# 15300
# 15350
# 15400
# 15450
# 15500
# 15550
# 15600
# 15650
# 15700
# 15750
# 15800
# 15850
# 15900
# 15950
# 16000
# 16050
# 16100
# 16150
# 16200
# 16250
# 16300
# 16350
# 16400
# 16450
# 16500
# 16550
# 16600
# 16650
# 16700
# 16750
# 16800
# 16850
# 16900
# 16950
# 17000
# 17050
# 17100
# 17150
# 17200
# 17250
# 17300
# 17350
# 17400
# 17450
# 17500
# 17550
# 17600
# 17650
# 17700
# 17750
# 17800
# 17850
# 17900
# 17950
# 18000
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050
# 19100
# 19150
# 19200
# 19250
# 19300
# 19350
# 19400
# 19450
# 19500
# 19550
# 19600
# 19650
# 19700
# 19750
# 19800
# 19850
# 19900
# 19950
# 20000
# 20050
# 20100
# 20150
# 20200
# 20250
# 20300
# 20350
# 20400
# 20450
# 20500
# 20550
# 20600
# 20650
# 20700
# 20750
# 20800
# 20850
# 20900
# 20950
# 21000
# 21050
# 21100
# 21150
# 21200
# 21250
# 21300
# 21350
# 21400
# 21450
# 21500
# 21550
# 21600
# 21650
# 21700
# 21750
# 21800
# 21850
# 21900
# 21950
# 22000
# 22050
# 22100
# 22150
# 22200
# 22250
# 22300
# 22350
# 22400
# 22450
# 22500
# 22550
# 22600
# 22650
# 22700
# 22750
# 22800
# 22850
# 22900
# 22950
# 23000
# 23050
# 23100
# 23150
# 23200
# 23250
# 23300
# 23350
# 23400
# 23450
# 23500
# 23550
# 23600
# 23650
# 23700
# 23750
# 23800
# 23850
# 23900
# 23950
# 24000
# 24050
# 24100
# 24150
# 24200
# 24250
# 24300
# 24350
# 24400
# 24450
# 24500
# 24550
# 24600
# 24650
# 24700
# 24750
# 24800
# 24850
# 24900
# 24950
# 25000
# 25050
# 25100
# 25150
# 25200
# 25250
# 25300
# 25350
# 25400
# 25450
# 25500
# 25550
# 25600
# 25650
# 25700
# 25750
# 25800
# 25850
# 25900
# 25950
# 26000
# 26050
# 26100
# 26150
# 26200
# 26250
# 26300
# 26350
# 26400
# 26450
# 26500
# 26550
# 26600
# 26650
# 26700
# 26750
# 26800
# 26850
# 26900
# 26950
# 27000
# 27050
# 27100
# 27150
# 27200
# 27250
# 27300
# 27350
# 27400
# 27450
# 27500
# 27550
# 27600
# 27650
# 27700
# 27750
# 27800
# 27850
# 27900
# 27950
# 28000
# 28050
# 28100
# 28150
# 28200
# 28250
# 28300
# 28350
# 28400
# 28450
# 28500
# 28550
# 28600
# 28650
# 28700
# 28750
# 28800
# 28850
# 28900
# 28950
# 29000
# 29050
# 29100
# 29150
# 29200
# 29250
# 29300
# 29350
# 29400
# 29450
# 29500
# 29550
# 29600
# 29650
# 29700
# 29750
# 29800
# 29850
# 29900
# 29950
# 30000

# %%
# ... compute time-frequency spectrum
f, t, Sxx = np.abs(signal.stft(Bx,1/dt,nperseg=500,noverlap=100,nfft=None))
om = 2*np.pi*f
lvls = np.logspace(-15,-3,200)
Time,Omega = np.meshgrid(t,om)
# .


plt.contourf(Time,Omega,Sxx,500,cmap = 'jet')
#plt.contourf(Time,Omega,Sxx,norm = LogNorm(),levels = lvls, cmap = 'jet')
#plt.contourf(Time,Omega,Sxx,norm = LogNorm(), cmap = 'jet')

#plt.plot(np.linspace(t[0],t[-1],100),np.ones(100)*omega_r*2,'k--')
plt.xlabel('t |wce|')
plt.ylabel('w / |wce|')
plt.ylim((0,1))
plt.xlim((1500,2500))
plt.colorbar()
plt.title('time-frequency spectrogram')

plt.figure()
#plt.plot(tn[10000:18000],Bx[10000:18000])
plt.plot(tn,Bx)

# %%
Nstart = 10000
Nend = 18000
Delta = Nend - Nstart
spec = np.fft.fft(Bx[Nstart:Nend+1])
spec = np.fft.fftshift(spec)
w = np.linspace(0,Delta,Delta+1) - Delta/2
w = 2*np.pi*w/(Delta*dt)
plt.plot(w,np.abs(spec))
plt.xlim((0,1))
# Out:
# (0, 1)

# %%
from Utils_Dipole.evaluation import evaluation

# ... compute 2D fft to investigate dispersion relation
w = np.linspace(0,Nt,Nt+1) - Nt/2
w = 2*np.pi/T*w

ks = np.linspace(0,Nz,Nz+1) - Nz/2
ks = 2*np.pi/Lz*ks

Bx = np.zeros((Nt+1,Nz+1))

for i in range(0,Nt+1):
    if i%50 == 0:
        print('time steps finished: ' + str(i))
    Bx[i] = evaluation(bjx[i],basis,zj,p,bcs_f)
# Out:
# time steps finished: 0
# time steps finished: 50
# time steps finished: 100
# time steps finished: 150
# time steps finished: 200
# time steps finished: 250
# time steps finished: 300
# time steps finished: 350
# time steps finished: 400
# time steps finished: 450
# time steps finished: 500
# time steps finished: 550
# time steps finished: 600
# time steps finished: 650
# time steps finished: 700
# time steps finished: 750
# time steps finished: 800
# time steps finished: 850
# time steps finished: 900
# time steps finished: 950
# time steps finished: 1000
# time steps finished: 1050
# time steps finished: 1100
# time steps finished: 1150
# time steps finished: 1200
# time steps finished: 1250
# time steps finished: 1300
# time steps finished: 1350
# time steps finished: 1400
# time steps finished: 1450
# time steps finished: 1500
# time steps finished: 1550
# time steps finished: 1600
# time steps finished: 1650
# time steps finished: 1700
# time steps finished: 1750
# time steps finished: 1800
# time steps finished: 1850
# time steps finished: 1900
# time steps finished: 1950
# time steps finished: 2000
# time steps finished: 2050
# time steps finished: 2100
# time steps finished: 2150
# time steps finished: 2200
# time steps finished: 2250
# time steps finished: 2300
# time steps finished: 2350
# time steps finished: 2400
# time steps finished: 2450
# time steps finished: 2500
# time steps finished: 2550
# time steps finished: 2600
# time steps finished: 2650
# time steps finished: 2700
# time steps finished: 2750
# time steps finished: 2800
# time steps finished: 2850
# time steps finished: 2900
# time steps finished: 2950
# time steps finished: 3000
# time steps finished: 3050
# time steps finished: 3100
# time steps finished: 3150
# time steps finished: 3200
# time steps finished: 3250
# time steps finished: 3300
# time steps finished: 3350
# time steps finished: 3400
# time steps finished: 3450
# time steps finished: 3500
# time steps finished: 3550
# time steps finished: 3600
# time steps finished: 3650
# time steps finished: 3700
# time steps finished: 3750
# time steps finished: 3800
# time steps finished: 3850
# time steps finished: 3900
# time steps finished: 3950
# time steps finished: 4000
# time steps finished: 4050
# time steps finished: 4100
# time steps finished: 4150
# time steps finished: 4200
# time steps finished: 4250
# time steps finished: 4300
# time steps finished: 4350
# time steps finished: 4400
# time steps finished: 4450
# time steps finished: 4500
# time steps finished: 4550
# time steps finished: 4600
# time steps finished: 4650
# time steps finished: 4700
# time steps finished: 4750
# time steps finished: 4800
# time steps finished: 4850
# time steps finished: 4900
# time steps finished: 4950
# time steps finished: 5000
# time steps finished: 5050
# time steps finished: 5100
# time steps finished: 5150
# time steps finished: 5200
# time steps finished: 5250
# time steps finished: 5300
# time steps finished: 5350
# time steps finished: 5400
# time steps finished: 5450
# time steps finished: 5500
# time steps finished: 5550
# time steps finished: 5600
# time steps finished: 5650
# time steps finished: 5700
# time steps finished: 5750
# time steps finished: 5800
# time steps finished: 5850
# time steps finished: 5900
# time steps finished: 5950
# time steps finished: 6000
# time steps finished: 6050
# time steps finished: 6100
# time steps finished: 6150
# time steps finished: 6200
# time steps finished: 6250
# time steps finished: 6300
# time steps finished: 6350
# time steps finished: 6400
# time steps finished: 6450
# time steps finished: 6500
# time steps finished: 6550
# time steps finished: 6600
# time steps finished: 6650
# time steps finished: 6700
# time steps finished: 6750
# time steps finished: 6800
# time steps finished: 6850
# time steps finished: 6900
# time steps finished: 6950
# time steps finished: 7000
# time steps finished: 7050
# time steps finished: 7100
# time steps finished: 7150
# time steps finished: 7200
# time steps finished: 7250
# time steps finished: 7300
# time steps finished: 7350
# time steps finished: 7400
# time steps finished: 7450
# time steps finished: 7500
# time steps finished: 7550
# time steps finished: 7600
# time steps finished: 7650
# time steps finished: 7700
# time steps finished: 7750
# time steps finished: 7800
# time steps finished: 7850
# time steps finished: 7900
# time steps finished: 7950
# time steps finished: 8000
# time steps finished: 8050
# time steps finished: 8100
# time steps finished: 8150
# time steps finished: 8200
# time steps finished: 8250
# time steps finished: 8300
# time steps finished: 8350
# time steps finished: 8400
# time steps finished: 8450
# time steps finished: 8500
# time steps finished: 8550
# time steps finished: 8600
# time steps finished: 8650
# time steps finished: 8700
# time steps finished: 8750
# time steps finished: 8800
# time steps finished: 8850
# time steps finished: 8900
# time steps finished: 8950
# time steps finished: 9000
# time steps finished: 9050
# time steps finished: 9100
# time steps finished: 9150
# time steps finished: 9200
# time steps finished: 9250
# time steps finished: 9300
# time steps finished: 9350
# time steps finished: 9400
# time steps finished: 9450
# time steps finished: 9500
# time steps finished: 9550
# time steps finished: 9600
# time steps finished: 9650
# time steps finished: 9700
# time steps finished: 9750
# time steps finished: 9800
# time steps finished: 9850
# time steps finished: 9900
# time steps finished: 9950
# time steps finished: 10000
# time steps finished: 10050
# time steps finished: 10100
# time steps finished: 10150
# time steps finished: 10200
# time steps finished: 10250
# time steps finished: 10300
# time steps finished: 10350
# time steps finished: 10400
# time steps finished: 10450
# time steps finished: 10500
# time steps finished: 10550
# time steps finished: 10600
# time steps finished: 10650
# time steps finished: 10700
# time steps finished: 10750
# time steps finished: 10800
# time steps finished: 10850
# time steps finished: 10900
# time steps finished: 10950
# time steps finished: 11000
# time steps finished: 11050
# time steps finished: 11100
# time steps finished: 11150
# time steps finished: 11200
# time steps finished: 11250
# time steps finished: 11300
# time steps finished: 11350
# time steps finished: 11400
# time steps finished: 11450
# time steps finished: 11500
# time steps finished: 11550
# time steps finished: 11600
# time steps finished: 11650
# time steps finished: 11700
# time steps finished: 11750
# time steps finished: 11800
# time steps finished: 11850
# time steps finished: 11900
# time steps finished: 11950
# time steps finished: 12000
# time steps finished: 12050
# time steps finished: 12100
# time steps finished: 12150
# time steps finished: 12200
# time steps finished: 12250
# time steps finished: 12300
# time steps finished: 12350
# time steps finished: 12400
# time steps finished: 12450
# time steps finished: 12500
# time steps finished: 12550
# time steps finished: 12600
# time steps finished: 12650
# time steps finished: 12700
# time steps finished: 12750
# time steps finished: 12800
# time steps finished: 12850
# time steps finished: 12900
# time steps finished: 12950
# time steps finished: 13000
# time steps finished: 13050
# time steps finished: 13100
# time steps finished: 13150
# time steps finished: 13200
# time steps finished: 13250
# time steps finished: 13300
# time steps finished: 13350
# time steps finished: 13400
# time steps finished: 13450
# time steps finished: 13500
# time steps finished: 13550
# time steps finished: 13600
# time steps finished: 13650
# time steps finished: 13700
# time steps finished: 13750
# time steps finished: 13800
# time steps finished: 13850
# time steps finished: 13900
# time steps finished: 13950
# time steps finished: 14000
# time steps finished: 14050
# time steps finished: 14100
# time steps finished: 14150
# time steps finished: 14200
# time steps finished: 14250
# time steps finished: 14300
# time steps finished: 14350
# time steps finished: 14400
# time steps finished: 14450
# time steps finished: 14500
# time steps finished: 14550
# time steps finished: 14600
# time steps finished: 14650
# time steps finished: 14700
# time steps finished: 14750
# time steps finished: 14800
# time steps finished: 14850
# time steps finished: 14900
# time steps finished: 14950
# time steps finished: 15000
# time steps finished: 15050
# time steps finished: 15100
# time steps finished: 15150
# time steps finished: 15200
# time steps finished: 15250
# time steps finished: 15300
# time steps finished: 15350
# time steps finished: 15400
# time steps finished: 15450
# time steps finished: 15500
# time steps finished: 15550
# time steps finished: 15600
# time steps finished: 15650
# time steps finished: 15700
# time steps finished: 15750
# time steps finished: 15800
# time steps finished: 15850
# time steps finished: 15900
# time steps finished: 15950
# time steps finished: 16000
# time steps finished: 16050
# time steps finished: 16100
# time steps finished: 16150
# time steps finished: 16200
# time steps finished: 16250
# time steps finished: 16300
# time steps finished: 16350
# time steps finished: 16400
# time steps finished: 16450
# time steps finished: 16500
# time steps finished: 16550
# time steps finished: 16600
# time steps finished: 16650
# time steps finished: 16700
# time steps finished: 16750
# time steps finished: 16800
# time steps finished: 16850
# time steps finished: 16900
# time steps finished: 16950
# time steps finished: 17000
# time steps finished: 17050
# time steps finished: 17100
# time steps finished: 17150
# time steps finished: 17200
# time steps finished: 17250
# time steps finished: 17300
# time steps finished: 17350
# time steps finished: 17400
# time steps finished: 17450
# time steps finished: 17500
# time steps finished: 17550
# time steps finished: 17600
# time steps finished: 17650
# time steps finished: 17700
# time steps finished: 17750
# time steps finished: 17800
# time steps finished: 17850
# time steps finished: 17900
# time steps finished: 17950
# time steps finished: 18000
# time steps finished: 18050
# time steps finished: 18100
# time steps finished: 18150
# time steps finished: 18200
# time steps finished: 18250
# time steps finished: 18300
# time steps finished: 18350
# time steps finished: 18400
# time steps finished: 18450
# time steps finished: 18500
# time steps finished: 18550
# time steps finished: 18600
# time steps finished: 18650
# time steps finished: 18700
# time steps finished: 18750
# time steps finished: 18800
# time steps finished: 18850
# time steps finished: 18900
# time steps finished: 18950
# time steps finished: 19000
# time steps finished: 19050
# time steps finished: 19100
# time steps finished: 19150
# time steps finished: 19200
# time steps finished: 19250
# time steps finished: 19300
# time steps finished: 19350
# time steps finished: 19400
# time steps finished: 19450
# time steps finished: 19500
# time steps finished: 19550
# time steps finished: 19600
# time steps finished: 19650
# time steps finished: 19700
# time steps finished: 19750
# time steps finished: 19800
# time steps finished: 19850
# time steps finished: 19900
# time steps finished: 19950
# time steps finished: 20000
# time steps finished: 20050
# time steps finished: 20100
# time steps finished: 20150
# time steps finished: 20200
# time steps finished: 20250
# time steps finished: 20300
# time steps finished: 20350
# time steps finished: 20400
# time steps finished: 20450
# time steps finished: 20500
# time steps finished: 20550
# time steps finished: 20600
# time steps finished: 20650
# time steps finished: 20700
# time steps finished: 20750
# time steps finished: 20800
# time steps finished: 20850
# time steps finished: 20900
# time steps finished: 20950
# time steps finished: 21000
# time steps finished: 21050
# time steps finished: 21100
# time steps finished: 21150
# time steps finished: 21200
# time steps finished: 21250
# time steps finished: 21300
# time steps finished: 21350
# time steps finished: 21400
# time steps finished: 21450
# time steps finished: 21500
# time steps finished: 21550
# time steps finished: 21600
# time steps finished: 21650
# time steps finished: 21700
# time steps finished: 21750
# time steps finished: 21800
# time steps finished: 21850
# time steps finished: 21900
# time steps finished: 21950
# time steps finished: 22000
# time steps finished: 22050
# time steps finished: 22100
# time steps finished: 22150
# time steps finished: 22200
# time steps finished: 22250
# time steps finished: 22300
# time steps finished: 22350
# time steps finished: 22400
# time steps finished: 22450
# time steps finished: 22500
# time steps finished: 22550
# time steps finished: 22600
# time steps finished: 22650
# time steps finished: 22700
# time steps finished: 22750
# time steps finished: 22800
# time steps finished: 22850
# time steps finished: 22900
# time steps finished: 22950
# time steps finished: 23000
# time steps finished: 23050
# time steps finished: 23100
# time steps finished: 23150
# time steps finished: 23200
# time steps finished: 23250
# time steps finished: 23300
# time steps finished: 23350
# time steps finished: 23400
# time steps finished: 23450
# time steps finished: 23500
# time steps finished: 23550
# time steps finished: 23600
# time steps finished: 23650
# time steps finished: 23700
# time steps finished: 23750
# time steps finished: 23800
# time steps finished: 23850
# time steps finished: 23900
# time steps finished: 23950
# time steps finished: 24000
# time steps finished: 24050
# time steps finished: 24100
# time steps finished: 24150
# time steps finished: 24200
# time steps finished: 24250
# time steps finished: 24300
# time steps finished: 24350
# time steps finished: 24400
# time steps finished: 24450
# time steps finished: 24500
# time steps finished: 24550
# time steps finished: 24600
# time steps finished: 24650
# time steps finished: 24700
# time steps finished: 24750
# time steps finished: 24800
# time steps finished: 24850
# time steps finished: 24900
# time steps finished: 24950
# time steps finished: 25000
# time steps finished: 25050
# time steps finished: 25100
# time steps finished: 25150
# time steps finished: 25200
# time steps finished: 25250
# time steps finished: 25300
# time steps finished: 25350
# time steps finished: 25400
# time steps finished: 25450
# time steps finished: 25500
# time steps finished: 25550
# time steps finished: 25600
# time steps finished: 25650
# time steps finished: 25700
# time steps finished: 25750
# time steps finished: 25800
# time steps finished: 25850
# time steps finished: 25900
# time steps finished: 25950
# time steps finished: 26000
# time steps finished: 26050
# time steps finished: 26100
# time steps finished: 26150
# time steps finished: 26200
# time steps finished: 26250
# time steps finished: 26300
# time steps finished: 26350
# time steps finished: 26400
# time steps finished: 26450
# time steps finished: 26500
# time steps finished: 26550
# time steps finished: 26600
# time steps finished: 26650
# time steps finished: 26700
# time steps finished: 26750
# time steps finished: 26800
# time steps finished: 26850
# time steps finished: 26900
# time steps finished: 26950
# time steps finished: 27000
# time steps finished: 27050
# time steps finished: 27100
# time steps finished: 27150
# time steps finished: 27200
# time steps finished: 27250
# time steps finished: 27300
# time steps finished: 27350
# time steps finished: 27400
# time steps finished: 27450
# time steps finished: 27500
# time steps finished: 27550
# time steps finished: 27600
# time steps finished: 27650
# time steps finished: 27700
# time steps finished: 27750
# time steps finished: 27800
# time steps finished: 27850
# time steps finished: 27900
# time steps finished: 27950
# time steps finished: 28000
# time steps finished: 28050
# time steps finished: 28100
# time steps finished: 28150
# time steps finished: 28200
# time steps finished: 28250
# time steps finished: 28300
# time steps finished: 28350
# time steps finished: 28400
# time steps finished: 28450
# time steps finished: 28500
# time steps finished: 28550
# time steps finished: 28600
# time steps finished: 28650
# time steps finished: 28700
# time steps finished: 28750
# time steps finished: 28800
# time steps finished: 28850
# time steps finished: 28900
# time steps finished: 28950
# time steps finished: 29000
# time steps finished: 29050
# time steps finished: 29100
# time steps finished: 29150
# time steps finished: 29200
# time steps finished: 29250
# time steps finished: 29300
# time steps finished: 29350
# time steps finished: 29400
# time steps finished: 29450
# time steps finished: 29500
# time steps finished: 29550
# time steps finished: 29600
# time steps finished: 29650
# time steps finished: 29700
# time steps finished: 29750
# time steps finished: 29800
# time steps finished: 29850
# time steps finished: 29900
# time steps finished: 29950
# time steps finished: 30000

# %%
from matplotlib.colors import LogNorm
from Utils.dispersionSolver import solveDispersionCold

Bxkw = np.fft.fft2(Bx)
K,W = np.meshgrid(ks,w)
Bkw = np.fft.fftshift(Bxkw)
Bkw_plot = np.abs(Bkw)/np.abs(Bkw).max()
plt.pcolor(K,W,Bkw_plot,cmap = 'inferno',norm = LogNorm(vmin = Bkw_plot.min(),vmax = Bkw_plot.max()))
plt.xlim((0,6))
plt.ylim((0,5))
plt.xlabel('k')
plt.ylabel('w')

# ... Newton method for cold plasma dispersion relation for fixed k
k1 = np.linspace(0.1,6.0,40)

w1_1 = np.zeros(40)
w1_2 = np.zeros(40)
w1_3 = np.zeros(40)

w1_1[0] = 0.0001 
w1_2[0] = 1.5001 
w1_3[0] = 2.5001


for i in range(0,40):
    
    if i == 0:
        w1_1[i] = solveDispersionCold(k1[i],+1,c,wce,wpe,w1_1[i],1e-6,100)[0]
        w1_2[i] = solveDispersionCold(k1[i],-1,c,wce,wpe,w1_2[i],1e-6,100)[0]
        w1_3[i] = solveDispersionCold(k1[i],+1,c,wce,wpe,w1_3[i],1e-6,100)[0]
    
    else:
        w1_1[i] = solveDispersionCold(k1[i],+1,c,wce,wpe,w1_1[i-1],1e-6,100)[0]
        w1_2[i] = solveDispersionCold(k1[i],-1,c,wce,wpe,w1_2[i-1],1e-6,100)[0]
        w1_3[i] = solveDispersionCold(k1[i],+1,c,wce,wpe,w1_3[i-1],1e-6,100)[0]
    
# ...

plt.plot(k1,w1_1,'k--')
plt.plot(k1,w1_2,'k--')
plt.plot(k1,w1_3,'k--')
